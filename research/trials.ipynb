# %%
# Config box
d = {"key":"val", "key1":"val1"}

# %%
d['key']
# Out:
# 'val'

# %%
d['key1']
# Out:
# 'val1'

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from box import ConfigBox
#
# ModuleNotFoundError: No module named 'box'

# %%
pip show python-box
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: python-box

# %%
pip install python-box pyyaml tqdm ensure
# Out:
# Collecting python-box
#   Downloading python_box-7.2.0-cp38-cp38-win_amd64.whl.metadata (8.0 kB)
# Collecting pyyaml
#   Downloading PyYAML-6.0.3-cp38-cp38-win_amd64.whl.metadata (2.2 kB)
# Collecting tqdm
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting ensure
#   Downloading ensure-1.0.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: colorama in c:\users\preadator\anaconda3\envs\kidney\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: six>=1.11.0 in c:\users\preadator\anaconda3\envs\kidney\lib\site-packages (from ensure) (1.16.0)
# Downloading python_box-7.2.0-cp38-cp38-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ----------------------------------- ---- 1.0/1.2 MB 10.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.0/1.2 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 2.7 MB/s eta 0:00:00
# Downloading PyYAML-6.0.3-cp38-cp38-win_amd64.whl (160 kB)
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading ensure-1.0.4-py3-none-any.whl (15 kB)
# Installing collected packages: tqdm, pyyaml, python-box, ensure
# Successfully installed ensure-1.0.4 python-box-7.2.0 pyyaml-6.0.3 tqdm-4.67.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"val", "key1":"val1"})

# %%
d2.key
# Out:
# 'val'

# %%
d2.key1
# Out:
# 'val1'

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
type(d)
# Out:
# dict

# %%
# ensure annotations 

def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(x=2, y=3)
# Out:
# 6

# %%
get_prodict(x=2, y="3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(x=2, y=3)
# Out:
# 6

# %%
get_prodict(x=2, y="3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 get_prodict(x=2, y="3")
#
# File c:\Users\PREADATOR\anaconda3\envs\kidney\lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_prodict at 0x000002BAEAAE6820> does not match annotation type <class 'int'>
